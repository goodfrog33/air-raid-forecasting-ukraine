# %% [markdown]
# # 06 · Explainability
#
# SHAP, permutation importance and model feature importance for the production count model.

# %%
import json
json.load(open('../reports/production_count_explainability.json'))

# %%
from IPython.display import Image
Image('../reports/figures/production_count_shap_summary.png')

# %%
import pandas as pd
pd.read_csv('../reports/production_count_permutation_importance.csv').head(15)

# %% [markdown]
# Recent-activity lags and recency (`time_since_last_alert`) dominate, with calendar features adding the diurnal/weekly structure.
