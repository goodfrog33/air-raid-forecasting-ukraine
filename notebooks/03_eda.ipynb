# %% [markdown]
# # 03 · Exploratory Data Analysis
#
# Temporal, geographic and statistical patterns. Figures are written to `reports/figures/` and a summary to `reports/eda_summary.json`.

# %%
from air_raid_forecasting.eda import run_eda
summary = run_eda()
summary

# %%
from IPython.display import Image
Image('../reports/figures/01_daily_timeseries.png')

# %%
Image('../reports/figures/06_hour_dow_heatmap.png')

# %%
Image('../reports/figures/11_decomposition.png')

# %% [markdown]
# ADF vs KPSS give the classic trend-stationary signature; the daily series shows strong weekly structure (see STL seasonal component).
